# %% [markdown]
# <a href="https://colab.research.google.com/github/AHamamd150/Zewail-city/blob/main/Hybrid_Quantum_classical_deepmodels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pennylane --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pennylane in /usr/local/lib/python3.7/dist-packages (0.27.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pennylane) (1.21.6)
# Requirement already satisfied: retworkx in /usr/local/lib/python3.7/dist-packages (from pennylane) (0.12.1)
# Requirement already satisfied: pennylane-lightning>=0.27 in /usr/local/lib/python3.7/dist-packages (from pennylane) (0.27.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pennylane) (1.7.3)
# Requirement already satisfied: autograd in /usr/local/lib/python3.7/dist-packages (from pennylane) (1.5)
# Requirement already satisfied: semantic-version>=2.7 in /usr/local/lib/python3.7/dist-packages (from pennylane) (2.10.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from pennylane) (1.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pennylane) (2.23.0)
# Requirement already satisfied: autoray>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from pennylane) (0.5.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from pennylane) (2.6.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.7/dist-packages (from pennylane) (5.2.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.7/dist-packages (from pennylane-lightning>=0.27->pennylane) (1.11.1)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd->pennylane) (0.16.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pennylane) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pennylane) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pennylane) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pennylane) (1.24.3)
# Requirement already satisfied: rustworkx==0.12.1 in /usr/local/lib/python3.7/dist-packages (from retworkx->pennylane) (0.12.1)

# %%
import os # To use the system comands in python
import matplotlib.pyplot as plt # plotting library
import numpy as np  #Numerical python liberary
import pandas as pd #Data handeling python module 
plt.style.use('seaborn')
import pennylane as qml 
from pennylane import numpy as np
from pennylane.optimize import AdamOptimizer
import matplotlib.pyplot as plt
import tensorflow as tf

tf.keras.backend.set_floatx('float64')

# %%
# !git clone https://github.com/AHamamd150/Zewail-city.git
# Out:
# fatal: destination path 'Zewail-city' already exists and is not an empty directory.

# %%
columns=['dr','met','ptj1','etaj1','ptj2','etaj2','ptZ','etaZ']
bkg=pd.DataFrame(np.load('Zewail-city/data/bkg.npz',allow_pickle=True)['arr_0'].T,columns=columns)
sig=pd.DataFrame(np.load('Zewail-city/data/Signal.npz',allow_pickle=True)['arr_0'].T,columns=columns)

# %%
signal_weight = 0.1 #weight of the signal events
bkg_weight = 0.1 # Weight of the background events
##########
fig= plt.figure(figsize=(20,10))
fig.subplots_adjust(hspace=1, wspace=1)
for q in range(8):
    y= fig.add_subplot(3,3,q+1)
    y.hist(sig.iloc[:,q],bins=50,fill=False,histtype='step',weights=np.ones(len((sig.iloc[:,q])))*signal_weight,log=True,label='Signal',linewidth=2,color='b');
    y.hist(bkg.iloc[:,q],bins=50,fill=False,histtype='step',weights=np.ones(len((bkg.iloc[:,q])))*bkg_weight,log=True,label='Background',linewidth=2,color='r');
    y.set_xlabel(columns[q]);
    y.set_ylabel('No. Events');
    plt.legend(loc='best',fontsize=10);
    plt.tight_layout()

# %%
sig['label']=np.ones(sig.shape[0])
bkg['label']=np.zeros(bkg.shape[0])

# %%
df = pd.concat([sig[:100],bkg[:100]],ignore_index=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,0:-1],df.iloc[:,-1],stratify=df.iloc[:,-1],test_size=0.2)

# %%
print('train sample shape= ',X_train.shape,' and test sample shape= ',X_test.shape)
print('train label shape= ',y_train.shape,'\t and test label shape= ',y_test.shape)
# Out:
# train sample shape=  (160, 8)  and test sample shape=  (40, 8)
# train label shape=  (160,) 	 and test label shape=  (40,)

# %%
from sklearn.preprocessing import StandardScaler
Sc = StandardScaler()
X_train = Sc.fit_transform(X_train)
X_test = Sc.transform(X_test)
y_train=tf.keras.utils.to_categorical(y_train,2)
y_test=tf.keras.utils.to_categorical(y_test,2)

# %%
n_qubits = 4
n_layers = 3
weights_init = 0.0 * np.random.randn(n_layers, n_qubits,3, requires_grad=True)#Initialize the weights

# %% [markdown]
# # Define the quantum layers

# %%
dev = qml.device("default.qubit",wires=n_qubits)

@qml.qnode(dev)
def qnode(inputs, weights):
    qml.AngleEmbedding(inputs, wires=range(n_qubits))
    qml.StronglyEntanglingLayers(weights, wires=range(n_qubits))
    return [qml.expval(qml.PauliZ(wires=i)) for i in range(n_qubits)]

# %% [markdown]
# # plot the quantum layers alone

# %%
qml.draw_mpl(qnode,expansion_strategy="device",decimals=1)(X_train[:,:4],weights_init)
# Out:
# /usr/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The datapath rcparam was deprecated in Matplotlib 3.2.1 and will be removed two minor releases later.
#   self[key] = other[key]
# /usr/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /usr/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
#   self[key] = other[key]
# /usr/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /usr/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# (<Figure size 1368x360 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0x7fbfe9793910>)

# %%
qml.drawer.use_style('default');
plt.figure(figsize=(20,20));
fig, ax = qml.draw_mpl(qnode, expansion_strategy="device")(X_train[:,:4],weights_init);
plt.show();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-9d63fbb58aa1> in <module>
#       1 qml.drawer.use_style('default');
#       2 plt.figure(figsize=(20,20));
# ----> 3 fig, ax = qml.draw_mpl(qnode, expansion_strategy="device")(X_train[:,:4],weights_init);
#       4 plt.show();
#
# /usr/local/lib/python3.7/dist-packages/pennylane/drawer/draw.py in wrapper(*args, **kwargs_qnode)
#     438         try:
#     439             qnode.expansion_strategy = expansion_strategy or original_expansion_strategy
# --> 440             qnode.construct(args, kwargs_qnode)
#     441         finally:
#     442             qnode.expansion_strategy = original_expansion_strategy
#
# /usr/local/lib/python3.7/dist-packages/pennylane/qnode.py in construct(self, args, kwargs)
#     585
#     586         if self.expansion_strategy == "device":
# --> 587             self._tape = self.device.expand_fn(self.tape, max_expansion=self.max_expansion)
#     588
#     589         # If the gradient function is a transform, expand the tape so that
#
# /usr/local/lib/python3.7/dist-packages/pennylane/_device.py in expand_fn(self, circuit, max_expansion)
#     699             return self.custom_expand_fn(circuit, max_expansion=max_expansion)
#     700
# --> 701         return self.default_expand_fn(circuit, max_expansion=max_expansion)
#     702
#     703     def batch_transform(self, circuit):
#
# /usr/local/lib/python3.7/dist-packages/pennylane/_device.py in default_expand_fn(self, circuit, max_expansion)
#     674
#     675         if ops_not_supported or obs_on_same_wire:
# --> 676             circuit = circuit.expand(depth=max_expansion, stop_at=self.stopping_condition)
#     677
#     678         return circuit
#
# /usr/local/lib/python3.7/dist-packages/pennylane/tape/qscript.py in expand(self, depth, stop_at, expand_measurements)
#    1054             self, depth=depth, stop_at=stop_at, expand_measurements=expand_measurements
#    1055         )
# -> 1056         new_script._update()
#    1057         return new_script
#    1058
#
# /usr/local/lib/python3.7/dist-packages/pennylane/tape/qscript.py in _update(self)
#     363
#     364         self._update_observables()  # Updates _obs_sharing_wires and _obs_sharing_wires_id
# --> 365         self._update_batch_size()  # Updates _batch_size; O(ops)
#     366
#     367         # The following line requires _batch_size to be up to date
#
# /usr/local/lib/python3.7/dist-packages/pennylane/tape/qscript.py in _update_batch_size(self)
#     450                 if op_batch_size != candidate:
#     451                     raise ValueError(
# --> 452                         "The batch sizes of the quantum script operations do not match, they include "
#     453                         f"{candidate} and {op_batch_size}."
#     454                     )
#
# ValueError: The batch sizes of the quantum script operations do not match, they include 160 and 3.

# %% [markdown]
# # Sequantial Quantum-Classical model

# %%
weight_shapes = {"weights": (n_layers, n_qubits)}
# re-define the layers
clayer_1 = tf.keras.layers.Dense(4,name='Classical_Layer')
qlayer_1 = qml.qnn.KerasLayer(qnode, weight_shapes, output_dim=n_qubits,name='Quantum_Layer')
clayer_2 = tf.keras.layers.Dense(2, activation="softmax",name="Classical_output")

# construct the model
inputs = tf.keras.Input(shape=(8,))
x = clayer_1(inputs)
x1 = qlayer_1(x)
outputs = clayer_2(x1)

model1 = tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# # Plot the model

# %%
tf.keras.utils.plot_model(model1,show_shapes=True,show_layer_names=True,show_layer_activations=True)

# %%
model1.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.2), loss='CategoricalCrossentropy', metrics=["accuracy"])

# %%
fitting = model1.fit(X_train, y_train, epochs=2, batch_size=10, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/2
# 13/13 [==============================] - 24s 2s/step - loss: 0.2898 - accuracy: 0.9141 - val_loss: 0.1800 - val_accuracy: 0.9375
# Epoch 2/2
# 13/13 [==============================] - 24s 2s/step - loss: 0.1065 - accuracy: 0.9688 - val_loss: 0.0352 - val_accuracy: 1.0000

# %% [markdown]
# # Non Sequential Hybrid model

# %%
weight_shapes = {"weights": (n_layers, n_qubits)}
# re-define the layers
clayer_1 = tf.keras.layers.Dense(8,name='Classical_Layer')
qlayer_1 = qml.qnn.KerasLayer(qnode, weight_shapes, output_dim=n_qubits,name='Quantum_Layer_1')
qlayer_2 = qml.qnn.KerasLayer(qnode, weight_shapes, output_dim=n_qubits,name='Quantum_Layer_2')
clayer_2 = tf.keras.layers.Dense(2, activation="softmax")

# construct the model
inputs = tf.keras.Input(shape=(8,))
x = clayer_1(inputs)
x_1, x_2 = tf.split(x, 2, axis=1)
x_1 = qlayer_1(x_1)
x_2 = qlayer_2(x_2)
x = tf.concat([x_1, x_2], axis=1)
outputs = clayer_2(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
tf.keras.utils.plot_model(model,show_shapes=True,show_layer_names=True,show_layer_activations=True)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.2), loss='CategoricalCrossentropy', metrics=["accuracy"])

# %%
hist = model.fit(X_train, y_train, epochs=2, batch_size=10, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/2
# 13/13 [==============================] - 51s 4s/step - loss: 0.2065 - accuracy: 0.9297 - val_loss: 0.1219 - val_accuracy: 0.9375
# Epoch 2/2
# 13/13 [==============================] - 67s 5s/step - loss: 0.0334 - accuracy: 0.9922 - val_loss: 0.0831 - val_accuracy: 0.9688

# %% [markdown]
# # Multi-inputs Hybrid model

# %%
weight_shapes = {"weights": (n_layers, n_qubits)}
# re-define the layers
clayer1 = tf.keras.layers.Dense(4,name='Classical_Layer_1')
clayer2 = tf.keras.layers.Dense(4,name='Classical_Layer_2')
qlayer1 = qml.qnn.KerasLayer(qnode, weight_shapes, output_dim=n_qubits,name='Quantum_Layer_1')
qlayer2 = qml.qnn.KerasLayer(qnode, weight_shapes, output_dim=n_qubits,name='Quantum_Layer_2')
clayer3 = tf.keras.layers.Dense(2, activation="softmax")

# construct the model
inputs1 = tf.keras.Input(shape=(8,))
inputs2 = tf.keras.Input(shape=(8,))
x1 = clayer1(inputs1)
x2 = clayer2(inputs2)
X_1 = qlayer1(x1)
X_2 = qlayer2(x2)
x = tf.concat([X_1, X_2], axis=1)
outputs = clayer3(x)

model2 = tf.keras.Model(inputs=[inputs1,inputs2], outputs=outputs)

# %%
tf.keras.utils.plot_model(model2,show_shapes=True,show_layer_names=True,show_layer_activations=True)

# %%
model2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.2), loss='CategoricalCrossentropy', metrics=["accuracy"])

# %%
hist2 = model2.fit([X_train,X_train], y_train, epochs=2, batch_size=10, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/2
# 13/13 [==============================] - 47s 4s/step - loss: 0.5269 - accuracy: 0.7266 - val_loss: 0.4205 - val_accuracy: 0.7500
# Epoch 2/2
# 13/13 [==============================] - 47s 4s/step - loss: 0.3939 - accuracy: 0.8125 - val_loss: 0.0990 - val_accuracy: 1.0000

# %%
n_qubits = 4
dev = qml.device('default.qubit',wires=n_qubits)
@qml.qnode(dev)
def circuit(distance, parameters):
    qml.AngleEmbedding(distance, wires=range(n_qubits))
    qml.BasicEntanglerLayers(parameters, wires=range(n_qubits))
    return qml.expval(qml.PauliZ(0))

n_layers = 6
weights = np.random.random([n_layers, n_qubits])
X = [1.5]

qml.draw_mpl(circuit,expansion_strategy="device",decimals=1)(X,weights)
# Out:
# /usr/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The datapath rcparam was deprecated in Matplotlib 3.2.1 and will be removed two minor releases later.
#   self[key] = other[key]
# /usr/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /usr/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
#   self[key] = other[key]
# /usr/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /usr/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# (<Figure size 3400x500 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0x7f3429904d90>)
